# %%
# !pip install Flask_SSLify
# Out:
# ...
# WARNING: Skipping C:\Users\hmcte\anaconda3\Lib\site-packages\aiobotocore-2.5.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\hmcte\anaconda3\Lib\site-packages\aiofiles-22.1.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\hmcte\anaconda3\Lib\site-packages\aiohttp-3.8.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\hmcte\anaconda3\Lib\site-packages\aiosqlite-0.18.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\hmcte\anaconda3\Lib\site-packages\anaconda_cloud_auth-0.1.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\hmcte\anaconda3\Lib\site-packages\anaconda_navigator-2.5.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\hmcte\anaconda3\Lib\site-packages\astropy-5.1.dist-info due to invalid metadata entry 'name'
# ...
